# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import ticker
import hist
import vector
import pandas as pd

from physics.simulation import msq, mcfm
from physics.analysis import zz4l

# %%
events = mcfm.from_csv('data/zz4l/ggZZ_sbi/events_*.csv')

# %%
events_analyzed = zz4l.analyze(events)
# Out:
# Inclusive | 1.000000004129661
# After cuts | 1.000000004129661

# %%
print(events_analyzed.weights)

plt.hist(events_analyzed.kinematics['Z1_mass'], weights = events_analyzed.weights, bins=500)
plt.show()

plt.hist(events_analyzed.kinematics['Z2_mass'], weights = events_analyzed.weights, bins=500)
plt.show()

plt.hist(events_analyzed.kinematics['l3_pt'], weights = events_analyzed.weights, bins=500)
plt.show()
# Out:
# 0          2.623205e-07
# 1          4.384898e-07
# 2          3.373049e-07
# 3          6.125433e-07
# 4          2.571829e-07
#                ...
# 2882267    2.778844e-07
# 2882268    1.953509e-07
# 2882269    3.687919e-07
# 2882270    1.948055e-07
# 2882271    3.924448e-07
# Name: wt, Length: 2882272, dtype: float64
